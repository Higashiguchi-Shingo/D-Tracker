# %%
import viztools as vz
import numpy as np
import sys
sys.path.append("../src")
import utils

# %%
dataset = "pythonlib"
time = 176
geo_list = utils.get_dim_list("../data/" + dataset + ".csv.gz", mode="geo")
key_list = utils.get_dim_list("../data/" + dataset + ".csv.gz", mode="query")
#data = utils.load_tensor("../data/pythonlib.csv.gz", time_key="date", facets=["query","geo"], values="volume", start_date="2010-01-01", end_date="2022-12-31", scale="full")

# %%
"""import matplotlib.pyplot as plt
plt.figure()
plt.plot(data[:,:,10], label=key_list)
plt.legend()
plt.show()"""
# Out:
# 'import matplotlib.pyplot as plt\nplt.figure()\nplt.plot(data[:,:,10], label=key_list)\nplt.legend()\nplt.show()'

# %%
#path = "../decompose/device/ts=0/te=104/stl=26/ablation_s=0/ablation_d=0/outlier=0/model/t=0-"
path = "../result/" + dataset + "/lc=104/stl=26/rankupdate=1/ablation_s=0/ablation_d=0/outlier=1/model/t=" + str(time) + "-"

# %%
Wkey = np.load(path + "/Wkey.npy")
Wloc = np.load(path + "/Wloc.npy")
Wcore = np.load(path + "/gen_Wcore.npy")

# %%
idx = 0
vz.key_heatmap(Wkey, key_list, save_path=None, yticklabels=True, xticklabels=False, linewidth=5, vmin=-0.8, vmax=0.7)

# %%
#vz.key_heatmap_column(Wkey, key_list, [0,1], save_path=None)

# %%
vz.loc_heatmap_column(Wloc, geo_list, [0,1])
# Out:
# /Users/higashiguchishingo/repo/D-Tracker/notebook/viztools.py:22: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gdf = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
vz.diff_map(Wloc, geo_list)
# Out:
# /Users/higashiguchishingo/repo/D-Tracker/notebook/viztools.py:22: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gdf = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
vz.latent_dynamics(Wcore, figsize=(5,5), linewidth=5,label_name=["2013-06","2014-06","2015-05"], color="orange")
